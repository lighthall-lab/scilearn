# %%
import os
import pandas as pd
import numpy as np
from convert_eprime import convert as ep

# %%
source_dir = os.path.join('..','sourcedata')
derivs_dir = os.path.join('..','derivatives')

# %% [markdown]
# #### Define a function to clean the N-back data
#
# Stack the blocks vertically instead of horizontally, label the trial rows properly, and tag each trial as a HIT, MISS, FA, CR. We are also ouputting a new CSV data file in the sourcedata folder, all cleaned-up.

# %%
def nstack_score_label(fpath,outpath):
    df = pd.read_excel(fpath)
    
    # Hierarchicalize the column index
    df.columns=pd.MultiIndex.from_tuples([
        (df.columns[0].split('.')[0],df.columns[0].split('.')[1]),
        (df.columns[1].split('.')[0],df.columns[1].split('.')[1]),
        (df.columns[2].split('.')[0],df.columns[2].split('.')[1]),
        (df.columns[3].split('.')[0],df.columns[3].split('.')[1]),
        (df.columns[4].split('.')[0],df.columns[4].split('.')[1]),
        (df.columns[5].split('.')[0],df.columns[5].split('.')[1]),
    ])
    
    # Stack blocks, Reset trial row index, and Rename columns to be descriptive
    df = df.stack(0).reset_index().rename(
        columns={'level_0':'trial','level_1':'block'}
    ).sort_values(['block','trial'])
    df['sub'] = os.path.basename(fpath).split('_')[0].split('-')[1]
    df['block'] = df['block'].str[1]
    df['trial'] = df['trial'] + 1
    df = df.set_index(['sub','block','trial'])
    
    # Determine Hits, CRs, FAs
    cr_mask = (df['Rsp'] == 0) & (df['CRsp'] == 0)
    ms_mask = (df['Rsp'] == 0) & (df['CRsp'] == 1)
    fa_mask = (df['Rsp'] == 1) & (df['CRsp'] == 0)
    ht_mask = (df['Rsp'] == 1) & (df['CRsp'] == 1)
    df['CR']   = cr_mask.astype(int)
    df['MISS'] = ms_mask.astype(int)
    df['FA']   = fa_mask.astype(int)
    df['HIT']  = ht_mask.astype(int)
    
    # Output to new CSV datafile
    df.to_csv(outpath)
    print('Output file successfully created- ',outpath)

# %% [markdown]
# #### Read all the subject data
#
# Reading only data for the full sample (100-series YA & 200-series OA). Executing N-back data cleaning & EPrime txt-to-csv conversion. Setting up for subject-level analysis.

# %%
ep_frames=[]
ptb_frames=[]

for s in os.listdir(source_dir):
    if s.startswith('sub-1') or s.startswith('sub-2'):
        sub_dir = os.path.join(source_dir,s)
        for f in os.listdir(sub_dir):
            o = f.split('.')[0]+'.csv'
            fpath = os.path.join(sub_dir,f)
            outpath = os.path.join(sub_dir,o)
            if f.split('_')[-1] == 'beh.txt':
                print(f)
                ep.text_to_csv(fpath,outpath)
                ep_frames.append(pd.read_csv(outpath))
            if f.split('_')[-1] == 'beh.xlsx':
                print(f)
                nstack_score_label(fpath,outpath)
                ptb_frames.append(pd.read_csv(outpath))
                ptb_frames[-1]['sub'] = f.split('_')[0].split('-')[1]
print("Done!")
# Out:
# sub-101_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-101\sub-101_task-nback_beh.csv
# sub-101_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-101\sub-101_task-procspeed_run-1_beh.csv
# sub-102_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-102\sub-102_task-nback_beh.csv
# sub-102_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-102\sub-102_task-procspeed_run-1_beh.csv
# sub-103_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-103\sub-103_task-nback_beh.csv
# sub-103_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-103\sub-103_task-procspeed_run-1_beh.csv
# sub-104_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-104\sub-104_task-nback_beh.csv
# sub-104_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-104\sub-104_task-procspeed_run-1_beh.csv
# sub-105_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-105\sub-105_task-nback_beh.csv
# sub-105_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-105\sub-105_task-procspeed_run-1_beh.csv
# sub-106_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-106\sub-106_task-nback_beh.csv
# sub-106_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-106\sub-106_task-procspeed_run-1_beh.csv
# sub-107_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-107\sub-107_task-nback_beh.csv
# sub-107_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-107\sub-107_task-procspeed_run-1_beh.csv
# sub-108_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-108\sub-108_task-nback_beh.csv
# sub-108_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-108\sub-108_task-procspeed_run-1_beh.csv
# sub-109_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-109\sub-109_task-nback_beh.csv
# sub-109_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-109\sub-109_task-procspeed_run-1_beh.csv
# sub-110_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-110\sub-110_task-nback_beh.csv
# sub-110_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-110\sub-110_task-procspeed_run-1_beh.csv
# sub-111_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-111\sub-111_task-nback_beh.csv
# sub-111_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-111\sub-111_task-procspeed_run-1_beh.csv
# sub-112_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-112\sub-112_task-nback_beh.csv
# sub-112_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-112\sub-112_task-procspeed_run-1_beh.csv
# sub-113_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-113\sub-113_task-nback_beh.csv
# sub-113_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-113\sub-113_task-procspeed_run-1_beh.csv
# sub-114_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-114\sub-114_task-nback_beh.csv
# sub-114_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-114\sub-114_task-procspeed_run-1_beh.csv
# sub-115_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-115\sub-115_task-nback_beh.csv
# sub-115_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-115\sub-115_task-procspeed_run-1_beh.csv
# sub-116_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-116\sub-116_task-nback_beh.csv
# sub-116_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-116\sub-116_task-procspeed_run-1_beh.csv
# sub-117_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-117\sub-117_task-nback_beh.csv
# sub-117_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-117\sub-117_task-procspeed_run-1_beh.csv
# sub-118_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-118\sub-118_task-nback_beh.csv
# sub-118_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-118\sub-118_task-procspeed_run-1_beh.csv
# sub-119_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-119\sub-119_task-nback_beh.csv
# sub-119_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-119\sub-119_task-procspeed_run-1_beh.csv
# sub-120_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-120\sub-120_task-nback_beh.csv
# sub-120_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-120\sub-120_task-procspeed_run-1_beh.csv
# sub-121_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-121\sub-121_task-nback_beh.csv
# sub-121_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-121\sub-121_task-procspeed_run-1_beh.csv
# sub-122_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-122\sub-122_task-nback_beh.csv
# sub-122_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-122\sub-122_task-procspeed_run-1_beh.csv
# sub-125_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-125\sub-125_task-nback_beh.csv
# sub-125_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-125\sub-125_task-procspeed_run-1_beh.csv
# sub-126_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-126\sub-126_task-nback_beh.csv
# sub-126_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-126\sub-126_task-procspeed_run-1_beh.csv
# sub-127_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-127\sub-127_task-nback_beh.csv
# sub-127_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-127\sub-127_task-procspeed_run-1_beh.csv
# sub-201_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-201\sub-201_task-nback_beh.csv
# sub-201_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-201\sub-201_task-procspeed_run-1_beh.csv
# sub-203_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-203\sub-203_task-nback_beh.csv
# sub-203_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-203\sub-203_task-procspeed_run-1_beh.csv
# sub-204_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-204\sub-204_task-nback_beh.csv
# sub-204_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-204\sub-204_task-procspeed_run-1_beh.csv
# sub-205_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-205\sub-205_task-nback_beh.csv
# sub-205_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-205\sub-205_task-procspeed_run-1_beh.csv
# sub-206_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-206\sub-206_task-nback_beh.csv
# sub-206_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-206\sub-206_task-procspeed_run-1_beh.csv
# sub-207_task-nback_beh.xlsx
# Output file successfully created-  ..\sourcedata\sub-207\sub-207_task-nback_beh.csv
# sub-207_task-procspeed_run-1_beh.txt
# Output file successfully created- ..\sourcedata\sub-207\sub-207_task-procspeed_run-1_beh.csv
# Done!
